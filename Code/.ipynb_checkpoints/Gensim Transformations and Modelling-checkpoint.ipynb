# %%
# Imports
import pickle as pic
import numpy as np
import seaborn as sb
import nltk, string
import pandas as pd
from gensim import corpora, models, similarities
from collections import defaultdict
from nltk.corpus import stopwords
import gensim
from itertools import compress

# %% [markdown]
# ### Prepare Data (BOW Model)

# %%
# Load Datasets
all_data = pic.load( open("../Data/all_data.p", "rb"))

# %%
# Get Text and Index
ann_text = all_data['ann_text'].values
ref_text = all_data['fragment'].values

# %%
# Define normalizer
stemmer = nltk.stem.porter.PorterStemmer()

stop = set(stopwords.words('english'))

def stem_tokens(tokens):
    return [stemmer.stem(item) for item in tokens if item not in stop]

def normalize(text):
    return stem_tokens(nltk.word_tokenize(
            text.lower().translate(None, string.punctuation)))

# %%
# Normalize our annotations and Referent Text
ann_text_bow = map(normalize, ann_text)
ref_text_bow = map(normalize, ref_text)

# %%
# Get frequency dictionary
frequency = defaultdict(int)
for text in ann_text_bow:
    for token in text:
        frequency[token] += 1

# %%
# Create Dictionary with our annotations (only including words that appear more than once)
ann_text_mult = [[token for token in text if frequency[token] > 1] 
         for text in ann_text_bow]

dictionary = corpora.Dictionary(ann_text_mult)
dictionary.num_docs
# Out:
# 103882

# %%
# Print Number of Words in the Dictionary
len(dictionary.values())
# Out:
# 28029

# %%
# Create our corpus
corpus_bow = [dictionary.doc2bow(text) for text in ann_text_mult]

# %%
# Print first five sparse vectors in the corpus
print corpus_bow[:5]
print len(corpus_bow)
# Out:
#  [[(0, 1), (1, 1), (2, 2), (3, 1), (4, 1), (5, 2), (6, 1), (7, 1), (8, 1), (9, 1), (10, 1), (11, 2), (12, 1), (13, 1), (14, 1), (15, 1), (16, 1), (17, 1), (18, 1)], [(1, 1), (11, 3), (13, 1), (19, 2), (20, 1), (21, 1), (22, 1), (23, 1), (24, 1), (25, 1), (26, 3), (27, 1), (28, 1), (29, 1), (30, 2), (31, 1), (32, 1), (33, 1), (34, 1), (35, 1), (36, 1), (37, 1), (38, 2), (39, 1), (40, 2), (41, 1), (42, 1), (43, 1), (44, 1)], [(11, 1), (45, 1), (46, 1), (47, 1), (48, 1), (49, 1)], [(11, 2), (50, 1), (51, 2), (52, 3), (53, 1), (54, 1), (55, 1), (56, 1), (57, 1), (58, 1), (59, 1), (60, 1), (61, 1), (62, 1), (63, 1), (64, 2), (65, 1), (66, 1), (67, 1), (68, 1), (69, 1), (70, 2), (71, 1), (72, 1), (73, 3), (74, 1), (75, 1), (76, 1), (77, 2), (78, 1)], [(2, 1), (4, 1), (10, 1), (11, 1), (13, 1), (20, 1), (71, 1), (79, 1), (80, 1), (81, 2), (82, 1), (83, 1), (84, 1), (85, 1), (86, 1), (87, 1), (88, 1), (89, 1), (90, 1), (91, 1), (92, 1), (93, 1), (94, 1), (95, 3), (96, 2), (97, 4), (98, 1), (99, 1), (100, 1), (101, 1), (102, 1), (103, 1), (104, 1), (105, 1), (106, 1), (107, 1), (108, 1), (109, 1), (110, 2), (111, 1), (112, 1), (113, 2)]]
# 103882

# %% [markdown]
# ## Artist Specific Corpus
# In order to limit similarity comparisons for our specified query, we need to create a dictionary of artist specific corpuses that we can compare over to subset our search space to minimzing computational expense

# %%
# Create dictionary for storing artist corpuses ad their associated id
artist_corpus_dict = {}

# Fill dictionary with artist specific corpuses
artist_ids = all_data['artist_id'].unique()
for artist_id in artist_ids:
    id_mask = list(all_data['artist_id'] == artist_id)
    artist_text = compress(ann_text_mult, id_mask)
    artist_corpus = [dictionary.doc2bow(text) for text in artist_text]
    artist_corpus_dict[artist_id] = artist_corpus

# %%
artist_corpus_dict.keys()
# Out:
# [132097,
#  2,
#  3,
#  4,
#  5,
#  1,
#  1032,
#  15369,
#  100874,
#  13,
#  1039,
#  1553,
#  1043,
#  20,
#  1557,
#  22,
#  11353,
#  47131,
#  2588,
#  2077,
#  34,
#  348422,
#  42,
#  555,
#  556,
#  45,
#  46,
#  1583,
#  44080,
#  1073,
#  23090,
#  241331,
#  140856,
#  59,
#  64,
#  4161,
#  67,
#  68,
#  69,
#  72,
#  73,
#  74,
#  76,
#  77,
#  1102,
#  82,
#  83,
#  24661,
#  86,
#  1111,
#  88,
#  89,
#  271,
#  92,
#  13157,
#  344,
#  685,
#  103,
#  105,
#  108,
#  110,
#  111,
#  112,
#  143985,
#  115,
#  464,
#  119,
#  448,
#  123,
#  1148,
#  127,
#  640,
#  12417,
#  130,
#  643,
#  132,
#  646,
#  4231,
#  535,
#  1181,
#  147,
#  148,
#  2197,
#  108185,
#  8346,
#  156,
#  157,
#  158,
#  3781,
#  161,
#  170,
#  1195,
#  173,
#  2736,
#  136370,
#  179,
#  1205,
#  182,
#  183,
#  186,
#  3264,
#  1218,
#  195,
#  197,
#  198,
#  78535,
#  72393,
#  202,
#  330443,
#  204,
#  20185,
#  223,
#  976,
#  228,
#  229,
#  745,
#  996586,
#  747,
#  748,
#  778477,
#  7922,
#  1267,
#  758,
#  2295,
#  249,
#  1274,
#  251,
#  554,
#  255,
#  185600,
#  649478,
#  129,
#  1581,
#  25560,
#  276,
#  47387,
#  288,
#  569121,
#  291,
#  1319,
#  810,
#  812,
#  301,
#  303,
#  1001264,
#  306,
#  11571,
#  1333,
#  2358,
#  1340,
#  49470,
#  835,
#  310,
#  326,
#  329,
#  759,
#  14157,
#  334,
#  848,
#  56,
#  338,
#  853,
#  343,
#  1665,
#  18779,
#  630109,
#  90978,
#  357,
#  358,
#  3431,
#  362,
#  365,
#  63342,
#  372,
#  1912,
#  568186,
#  18814,
#  383,
#  388,
#  26092,
#  1421,
#  401,
#  402,
#  627,
#  405,
#  411,
#  416,
#  16808,
#  1180,
#  1450,
#  168690,
#  304,
#  432,
#  652275,
#  236,
#  438,
#  3520,
#  458,
#  1995,
#  974,
#  52688,
#  467,
#  322517,
#  471,
#  9688,
#  250,
#  47589,
#  337,
#  11240,
#  492,
#  594,
#  1007,
#  498,
#  2035,
#  14325,
#  8200,
#  1529,
#  506,
#  1020,
#  2046,
#  85]

# %% [markdown]
# ## TFIDF and Similarity Calculation

# %%
# Tf-Idf our corpus
tfidf = models.TfidfModel(corpus_bow)
corpus_tfidf = tfidf[corpus_bow]

# %%
# Create indices for querying separated by artist_id
artist_index_dict = {}
for key, value in artist_corpus_dict.iteritems():
    artist_index_dict[key] = similarities.MatrixSimilarity(tfidf[value])

# %%
# Randomly Sample 100 referents to compare
ref_indices = np.random.choice(range(all_data.shape[0]), 100, replace=False)

# %%
# Get the index for the "correct" annotation for each referent
ref_artist_id = all_data.iloc[ref_indices[0], :]['artist_id']
ref_ann_id = all_data.iloc[ref_indices[0], :]['ann_id']
artist_df = all_data[all_data['artist_id'] == ref_artist_id].reset_index(drop=True)
index = artist_df[artist_df['ann_id'] == ref_ann_id].index[0]
index

# %%
# Create TDIDF representation of our test query (referent)
doc = ref_text_bow[ref_indices[0]]
doc_bow = dictionary.doc2bow(doc)
doc_tfidf = tfidf[doc_bow]

# Query our index for closely related documents
sims_tfidf = artist_index_dict[ref_artist_id][doc_tfidf]
sims_tfidf = sorted(enumerate(sims_tfidf), 
                    key=lambda item: item[1], reverse=True)
sims_tfidf = np.array(sims_tfidf)
sims_tfidf[4][:]

# %%
# Create Function for calucating TFIDF searcha accuracy
def search_accuracy_tfidf(index):
    ref_artist_id = all_data.iloc[index, :]['artist_id']
    ref_ann_id = all_data.iloc[index, :]['ann_id']
    artist_df = all_data[all_data['artist_id'] == ref_artist_id].reset_index(drop=True)
    ref_position = artist_df[artist_df['ann_id'] == ref_ann_id].index[0]
    doc = ref_text_bow[index]
    doc_bow = dictionary.doc2bow(doc)
    doc_tfidf = tfidf[doc_bow]
    print doc_tfidf
    sims_tfidf = artist_index_dict[ref_artist_id][doc_tfidf]
    sims_tfidf = sorted(enumerate(sims_tfidf), 
                        key=lambda item: item[1], reverse=True)
    sims_tfidf = np.array(sims_tfidf)
    correct_position = np.where(sims_tfidf[:, 0] == ref_position)[0][0]
    percentile = 1 - correct_position/float(sims_tfidf.shape[0])
    return correct_position, percentile

# %%
scores = []
for idx in ref_indices:
    print idx
    accuracy = search_accuracy_tfidf(idx)
    scores.append(accuracy)
# Out:
# 50888
# [(4, 0.079370335248297), (27, 0.10072152860896998), (83, 0.16971580360208702), (85, 0.13779271034689036), (436, 0.1913632995573451), (438, 0.13466412582417508), (619, 0.4201503976903296), (691, 0.13061177328778079), (1285, 0.12383878842109806), (1687, 0.17263681354120147), (2672, 0.21699039284056174), (3399, 0.2061870919675847), (4430, 0.26836795546246284), (5221, 0.29565780067639197), (5913, 0.30346696750863505), (13891, 0.34082598769883476), (23706, 0.43011416632322685)]
# 34177
# [(2, 0.07104873556955503), (290, 0.10279858974383073), (545, 0.20420345657190062), (704, 0.1339839753619566), (1823, 0.19527998582116018), (2458, 0.15587609636197367), (3786, 0.25368179109635713), (4006, 0.2222088515576143), (4270, 0.23563227570037465), (4818, 0.23116231842037896), (6176, 0.2512892090809866), (11127, 0.3202067721832947), (12254, 0.30910392407885), (14209, 0.3988119098472773), (14779, 0.26822313246098584), (19809, 0.3839190802775997)]
# 63751
# [(59, 0.2744513850402358), (164, 0.19054772955554364), (428, 0.32026359931636217), (544, 0.4685841771686011), (1081, 0.49673025978435564), (2355, 0.5652319390174656)]
# 69840
# [(133, 0.2421127868801079), (256, 0.2333303673547636), (348, 0.2788530483405167), (574, 0.36704810985720654), (816, 0.274326789986432), (1041, 0.37305641099253767), (1256, 0.4755773623400479), (3441, 0.4835854624815369)]
# 3637
# [(53, 0.21585641296744768), (85, 0.5714578336572529), (134, 0.3663135685167626), (455, 0.31709636812725916), (742, 0.28512966487082214), (2089, 0.557500933079269)]
# 56152
# [(4, 0.18625473480798405), (94, 0.2624956746376594), (151, 0.3870730248010465), (256, 0.2473767559420431), (564, 0.30880440102252615), (603, 0.32277508097104785), (650, 0.4678829287031954), (1999, 0.5166488775662442)]
# 9336
# [(1349, 0.7476886825959261), (12112, 0.6640494212917954)]
# 64695
# [(428, 0.3517603227296679), (472, 0.30093602896283017), (1821, 0.4848060255366048), (2900, 0.46715896786609923), (3134, 0.576565519408579)]
# 23115
# [(947, 0.33902163854577916), (4218, 0.5915930331676613), (8532, 0.7314930018156165)]
# 72805
# [(29, 0.21735073880090508), (336, 0.3530781197283218), (517, 0.33924697361000866), (1798, 0.5116515207933283), (3103, 0.45898921000038606), (4620, 0.490456537301074)]
# 103605
# [(161, 0.39662985291241054), (269, 0.3579668017352936), (272, 0.338452201540176), (273, 0.24985827130452357), (330, 0.2809130597737342), (336, 0.37935490341669753), (3835, 0.561019777075349)]
# 48527
# [(160, 0.17919760560873463), (177, 0.2123990930187218), (340, 0.4164030288283627), (405, 0.30145658189412133), (1035, 0.3236487115977408), (2227, 0.35067633109354907), (3234, 0.4970863741999559), (4331, 0.42859077115685873)]
# 95573
# [(2085, 0.3800701457250001), (3527, 0.5347343223803478), (9249, 0.48961494979049847), (9377, 0.5743544983184646)]
# 98754
# [(344, 0.7345795214145647), (543, 0.3836345162190554), (3506, 0.5596583642578036)]
# 4720
# [(2, 0.1876249744390776), (269, 0.37860086124289544), (418, 0.36611260413871394), (898, 0.3253566849321005), (8210, 0.7626026786562163)]
# 50798
# [(879, 0.44360779908443954), (5019, 0.896221022176706)]
# 10238
# [(53, 0.24372097647073052), (555, 0.3774199123174094), (946, 0.44102649988672665), (11905, 0.7769491114687859)]
# 1060
# [(2, 0.13755597973253683), (23, 0.20659992419233342), (2338, 0.49393713012446855), (4732, 0.4146364582319021), (4761, 0.722839915024656)]
# 80604
# [(83, 0.18347173516665333), (785, 0.24673291883464887), (1425, 0.3800101585532466), (1794, 0.6044530335325677), (9274, 0.6290387895892312)]
# 31880
# [(4, 0.1413529867464492), (100, 0.20368723713793643), (250, 0.24691466368649578), (330, 0.20312495330303507), (428, 0.26798662450829575), (2040, 0.345895173354853), (4907, 0.43643086716475105), (20814, 0.6740712433322505)]
# 70562
# [(202, 0.21193355746552617), (1497, 0.393391321015575), (2635, 0.5313440761871738), (5349, 0.5771385351719254), (6888, 0.4300139761566248)]
# 92846
# [(2, 0.12087598279882146), (10, 0.07312452227863157), (81, 0.11704521015586761), (93, 0.08568993170247313), (143, 0.0857022026012024), (148, 0.07281148586775227), (150, 0.09096687532691142), (164, 0.050082376851169653), (185, 0.06849258736209804), (190, 0.09026756067564802), (232, 0.10701443667482806), (239, 0.08439396251449206), (250, 0.07755726714225311), (269, 0.16260717717361536), (330, 0.12760535183591679), (341, 0.08588713885588363), (343, 0.06918078868338767), (363, 0.07379970175139343), (402, 0.08978417770770394), (404, 0.13708535916197595), (434, 0.10831782788687917), (471, 0.11136581722116658), (472, 0.21604156925131768), (479, 0.123085746724915), (485, 0.20895545869181317), (528, 0.09592139520631088), (532, 0.0879555739472168), (555, 0.1803521355520578), (691, 0.07306421384019735), (694, 0.07411398876974054), (704, 0.07598279580600759), (709, 0.10711713129528329), (732, 0.078491116882849), (784, 0.07548084742147604), (855, 0.08370240465852044), (945, 0.12477766045391953), (1028, 0.07560142576102333), (1242, 0.08849591961039852), (1359, 0.12078059954669809), (1386, 0.0983197390611772), (1446, 0.0969908820174308), (1490, 0.10293407140284015), (1556, 0.10943798216485602), (1592, 0.11262335960024586), (1722, 0.13326353380223202), (1755, 0.11066245854124766), (1855, 0.1231597427174402), (1933, 0.0952312755312299), (1968, 0.2392461757662915), (1997, 0.12406882589565024), (2027, 0.10059953560307447), (2056, 0.25996980046509915), (2420, 0.10594942005664698), (2818, 0.11627854156121985), (3952, 0.1506731949322453), (4042, 0.15181484227668304), (4283, 0.1020545803449359), (4940, 0.15870648655454525), (6402, 0.1579052396952076), (6569, 0.14856203768063467), (6768, 0.1599692883327159), (8216, 0.14553113654027425), (9547, 0.18717831432392132), (15738, 0.21772189550248242)]
# 15031
# [(432, 0.39538376913878254), (1075, 0.41195922840521676), (3103, 0.42881844084453913), (4232, 0.7000542936266064)]
# 57455
# [(1887, 1.0)]
# 6056
# [(2, 0.09037409017082808), (50, 0.18317165773216887), (80, 0.15684480839744), (272, 0.1724207307918225), (280, 0.3148441266680791), (2174, 0.36617229535270535), (3559, 0.2582528028482734), (5771, 0.3049534886300649), (10119, 0.3874525277050071), (10259, 0.45596113369083235), (10261, 0.3911921960519016)]
# 54067
# [(23, 0.18537275418410754), (43, 0.26938431668922025), (574, 0.2841583063496233), (870, 0.2742095523689562), (2056, 0.26544717136931556), (8382, 0.4320881220599006), (18670, 0.6927985740725716)]
# 99629
# [(36, 0.22640776027643714), (92, 0.15068221506595883), (120, 0.10099924287936415), (315, 0.11377410865250642), (330, 0.09703628346456769), (481, 0.12828313275098094), (816, 0.10544461135533383), (971, 0.14597664043855396), (1035, 0.15183827401302843), (1104, 0.23904249783821943), (1241, 0.6021753562934008), (1762, 0.2680094746012018), (2861, 0.19594020494365483), (3384, 0.39491254106960777), (3512, 0.24137369468288666), (9773, 0.27809800123256895)]
# 69430
# [(202, 0.23616079339262294), (393, 0.26995524220561656), (943, 0.29189793870889297), (6011, 0.5075707855347513), (25831, 0.7269936299026345)]
# 102405
# [(204, 0.15698616967331563), (348, 0.2558869630989196), (691, 0.2652873682569387), (2076, 0.4699291682083229), (5546, 0.52308309682908), (26211, 0.5874099655005467)]
# 14601
# [(164, 0.15231099727471598), (1174, 0.31922707619288404), (3705, 0.40789882793898957), (7206, 0.4851939205478026), (14607, 0.6878232618659936)]
# 53218
# [(2, 0.19669202043762726), (4, 0.21674474790714396), (428, 0.4109194627470162), (436, 0.5225754684225803), (438, 0.36774119590887083), (2578, 0.5806551912460358)]
# 93046
# [(269, 0.23561427373689686), (330, 0.18489738780508871), (751, 0.40437728110107823), (842, 0.35909893400841475), (1202, 0.3257333794634164), (1946, 0.4039075199604908), (2638, 0.3175928424693185), (3048, 0.4113693530358577), (3157, 0.2801648849078614)]
# 57359
# [(83, 0.2049534953529989), (460, 0.32625238332294126), (795, 0.5743425663065117), (857, 0.3742580554368717), (1930, 0.6177499264166291)]
# 14598
# [(2326, 0.2809585512918536), (2895, 0.27664865063200444), (3651, 0.3703222935418483), (8095, 0.4050868580018848), (8569, 0.42487241393469594), (14212, 0.6023099574279378)]
# 13031
# [(85, 1.0)]
# 47215
# [(15, 0.34567953393359485), (120, 0.3090027089522153), (564, 0.34252809044508137), (898, 0.3251077191474849), (1570, 0.45655099823076245), (2136, 0.594612184453788)]
# 54157
# [(8418, 0.6753011907916007), (24384, 0.7375420677598303)]
# 82292
# [(23, 0.2552042995963995), (117, 0.29085999872225166), (390, 0.4594375825694212), (743, 0.45679199291631395), (1361, 0.42298191596531354), (2578, 0.5016131061958246)]
# 50881
# [(357, 0.5624798985973428), (2402, 0.8268109600591436)]
# 1420
# [(158, 0.5717137455865097), (262, 0.40162125760402734), (445, 0.7154325674359554)]
# 72666
# [(963, 0.542549374255155), (1671, 0.5647118600005965), (3651, 0.6218847897078739)]
# 61452
# [(2, 0.18825493760420756), (2489, 0.6243452329434507), (9234, 0.7581247315372479)]
# 2753
# [(120, 0.3216831072260864), (436, 0.5185449848167025), (438, 0.36490490727521074), (761, 0.48302143017731863), (2326, 0.5110438179674454)]
# 41670
# [(428, 0.3433706129498728), (555, 0.3678456999621196), (4910, 0.6335855205972184), (5546, 0.587669593624988)]
# 14122
# [(61, 0.2339279009802175), (272, 0.2796549404059182), (447, 0.2649816944061997), (451, 0.3439493771896368), (1464, 0.37591370491363146), (1909, 0.3452577113281505), (2268, 0.34449750405042234), (4622, 0.5471396969144317)]
# 83697
# [(4, 0.24404203191390222), (83, 0.13045739768323192), (85, 0.21183741325258182), (248, 0.26118747989785734), (704, 0.20881865855148143), (854, 0.2369645069723465), (3260, 0.7435901345646071), (7955, 0.39704743645365115)]
# 56192
# [(4, 0.13661717847488902), (27, 0.17336818607592486), (81, 0.18007289934980833), (85, 0.23717741953727883), (133, 0.09413981621887656), (250, 0.11932108918728795), (272, 0.11826575762523975), (330, 0.19631957298420036), (363, 0.11354011196038963), (502, 0.1296800617568269), (550, 0.14519701323257309), (857, 0.13335988672871588), (1068, 0.23267539651113836), (1205, 0.1992746130065781), (1860, 0.42642194133468214), (1868, 0.16009331868574259), (2028, 0.5810741545211031), (2466, 0.1609245429960272), (5312, 0.23138475826139893)]
# 51304
# [(873, 0.2913959210132046), (1855, 0.3454722738599787), (3598, 0.5819706259348704), (4076, 0.3769357564977559), (9672, 0.561219165062386)]
# 88004
# [(4, 0.15632065680744123), (127, 0.34283089781065407), (225, 0.2503221395359041), (250, 0.27306011207316117), (507, 0.2952077918365937), (694, 0.2609371735924531), (702, 0.2837730907998031), (1252, 0.4816323632709062), (1784, 0.5030656816748128)]
# 100376
# [(256, 0.601383553721691), (619, 0.7989604629223337)]
# 55881
# [(691, 0.28293347150484255), (1505, 0.3831197001335425), (6110, 0.5669869140652238), (12886, 0.6720816805646448)]
# 42496
# [(61, 0.16052625241519666), (129, 0.18408148442988195), (619, 0.19558166829372084), (3365, 0.4312365431901333), (5494, 0.39723197297942003), (6942, 0.4038793853008987), (8038, 0.48640252418301627), (11903, 0.39828252592943214)]
# 32721
# [(199, 0.6285210162334788), (1085, 0.7777926022744336)]
# 70868
# [(338, 1.0)]
# 16769
# [(2, 0.16112719409905674), (18, 0.2854023470892576), (61, 0.2571425317725162), (83, 0.18982996159407034), (124, 0.48091105035076537), (661, 0.32208850431322555), (2018, 0.550549267476447), (2063, 0.39026259461222096)]
# 71393
# [(330, 0.23778788728640268), (428, 0.6274361886771692), (1104, 0.2928874051187772), (3127, 0.5482614663874157), (7977, 0.40423641869040783)]
# 23784
# [(399, 0.16213462340895218), (580, 0.16743897471246413), (1744, 0.34641309508361434), (1963, 0.2544983949377365), (2146, 0.5174350397350522), (2190, 0.5979855514749274), (9003, 0.368211010223207)]
# 78035
# [(512, 0.26879407681418793), (590, 0.3492147945376615), (1037, 0.4815483517742384), (5420, 0.49576474554003147), (10544, 0.5728239463646483)]
# 74103
# [(164, 0.2374544308081967), (330, 0.6050123435299705), (728, 0.5428419172306372), (1354, 0.5318816695123967)]
# 98915
# [(12165, 1.0)]
# 23777
# [(680, 0.5714137541249272), (1838, 0.506530833725593), (6277, 0.6456878782214458)]
# 72017
# [(266, 0.368949417946985), (871, 0.44782915659705413), (1063, 0.38300824399062644), (2050, 0.5377750759613337), (2833, 0.4768941457054705)]
# 52724
# [(85, 0.42638825295535854), (120, 0.1224498341869597), (132, 0.11065051403050566), (438, 0.13890236815716137), (694, 0.13665814817224348), (1320, 0.19394960142315557), (1366, 0.1655798176187379), (2076, 0.7159408537781147), (4553, 0.23719742143181904), (10970, 0.34513648824083865)]
# 62588
# [(83, 0.19801274860131934), (85, 0.3215341498424569), (447, 0.3038338500136598), (757, 0.44359345087063873), (3570, 0.534222326927179), (14396, 0.5319051505856136)]
# 78667
# [(817, 0.7977607886024737), (3775, 0.6029740659169011)]
# 51693
# [(85, 0.19835463651113217), (661, 0.20726161017872047), (10554, 0.5602680159535968), (22662, 0.5148512740200689), (24026, 0.582001700220878)]
# 78602
# [(132, 0.1893783106652532), (290, 0.18397622921044338), (662, 0.26507104696621353), (988, 0.29307646370095014), (1251, 0.3404690690809502), (3853, 0.41201584386685564), (6568, 0.5105539032773057), (16175, 0.47727413325048745)]
# 11127
# [(256, 0.24903592296081667), (661, 0.3401378552331729), (1418, 0.7478076038413594), (2828, 0.5129046072609171)]
# 55941
# [(18, 0.2287049838334703), (1324, 0.2649180353275649), (2065, 0.5072880131559446), (2202, 0.3626495304934603), (2945, 0.5154717754667918), (5480, 0.47217105307949087)]
# 65487
# [(6609, 1.0)]
# 1883
# [(290, 0.4364622051056373), (550, 0.7065778956080213), (591, 0.5569994802084329)]
# 69675
# [(256, 0.21806042225527295), (580, 0.5642341476008618), (661, 0.2978309452520976), (2063, 0.3608706175271007), (2502, 0.32708560592665115), (8927, 0.5551338674395822)]
# 70366
# [(4, 0.11693032780792807), (120, 0.1748917888785161), (148, 0.19175489378889993), (438, 0.19839049850714502), (871, 0.26473903262627224), (1023, 0.2079615663232588), (1366, 0.23649317859675348), (1922, 0.39326956086403736), (3103, 0.2949788642001302), (10843, 0.4138241502570354), (13858, 0.5453656885819225)]
# 18371
# [(330, 0.28955495308052), (573, 0.4830639391575894), (604, 0.3887187651586925), (857, 0.3933893616166789), (3503, 0.6139622884285433)]
# 80994
# [(148, 0.4510158643337677), (160, 0.34240195994838796), (174, 0.48485955157682403), (1792, 0.6665259208669143)]
# 60899
# [(19, 0.24362704691077436), (30, 0.30680771554494674), (256, 0.2085668405419574), (273, 0.20071220584928992), (463, 0.37202029859279645), (1104, 0.27794761468411716), (1324, 0.2923859139151241), (2419, 0.34886165398815394), (8200, 0.5829934954972377)]
# 23945
# [(85, 0.22571979831722624), (1731, 0.2934246668875198), (4926, 0.5249734821082748), (7699, 0.48269371130593264), (21130, 0.5952832616984932)]
# 62909
# [(2, 0.08930733581479151), (18, 0.158188835822216), (83, 0.10521630580476833), (85, 0.1708507945850247), (250, 0.17190593386310551), (460, 0.1674871193297695), (661, 0.17852272782148293), (855, 0.18552665107473124), (1028, 0.3351416102115483), (1841, 0.237577843010456), (1965, 0.354572445800764), (1968, 0.2651449618050984), (10332, 0.34275614780369174), (12028, 0.43729695915838834), (12646, 0.359651124430228)]
# 38680
# [(728, 0.6593357928515748), (1566, 0.7518485966368397)]
# 102909
# [(276, 0.16210537550806428), (1186, 0.4847362058312953), (1472, 0.24878654960939298), (1616, 0.4573367906981728), (1951, 0.21076087331988333), (2054, 0.25122218456600137), (2214, 0.18298984858621772), (3715, 0.25155797255914275), (4254, 0.295974222249236), (6568, 0.32339090850123176), (12641, 0.26686910775393036)]
# 28261
# [(85, 0.2838210328262688), (132, 0.220960190323421), (181, 0.24432584724471815), (307, 0.3927910441415856), (336, 0.31725509757327625), (428, 0.3099450302831511), (694, 0.2728953470659914), (2849, 0.45321440835857985), (3283, 0.4243234644707303)]
# 98326
# [(330, 0.43182970566044976), (708, 0.9019551570389791)]
# 78245
# [(1809, 0.4283349557850842), (4887, 0.580730474191615), (6141, 0.6923014386795479)]
# 101999
# [(6, 0.18024425946177944), (123, 0.2672925850716243), (216, 0.2534511230989042), (812, 0.3070350171360341), (989, 0.4623955461537033), (1765, 0.2850260032585635), (1905, 0.3650812673382604), (1966, 0.30388044456223023), (2272, 0.34558512160985405), (3598, 0.3121738475367595)]
# 77325
# [(142, 0.20660673716545255), (205, 0.2605801037823354), (1745, 0.2905177483633894), (1963, 0.347037457009751), (3383, 0.4800524864668195), (3987, 0.4293539365659482), (9976, 0.5194043842528212)]
# 60001
# [(19, 0.43248807660707744), (61, 0.13457497487334155), (269, 0.17015714401531593), (661, 0.1685643058585506), (662, 0.35157712902013255), (1138, 0.2374223564574067), (1472, 0.5209535637191772), (2136, 0.5348904488902271)]
# 48634
# [(4, 0.3865624500342766), (18, 0.310682309197229), (85, 0.33555035103433206), (315, 0.3256546215204938), (330, 0.2777460930230104), (431, 0.3504096921651757), (709, 0.4663027731212089), (1744, 0.3435591413499075)]
# 16292
# [(261, 0.2861050304854895), (619, 0.3382426293032309), (854, 0.3722645633571693), (2349, 0.5497409730226359), (3331, 0.6024448461905503)]
# 63435
# [(428, 0.39214664893659607), (1241, 0.6148458374611663), (2046, 0.6842408946303012)]
# 9188
# [(4, 0.11317156514031404), (29, 0.13519471000556402), (261, 0.16891171988413783), (359, 0.1873553990261006), (360, 0.22029468537233363), (507, 0.21372177245210353), (543, 0.1724220633794775), (555, 0.22985185394628993), (1405, 0.3006234975850773), (1578, 0.3916521242446957), (1915, 0.29665732584791016), (5451, 0.45423126004640346), (7945, 0.4363667094744566)]
# 20587
# [(2, 0.09567745153454027), (104, 0.2669077711123611), (148, 0.17289830243277216), (216, 0.19999317821144524), (545, 0.2749896414443112), (662, 0.19945318808683077), (982, 0.27038789469651253), (1466, 0.2872791873067059), (2467, 0.32317535414182075), (2893, 0.2808928428740813), (5009, 0.36882613628820493), (5104, 0.3493234366924116), (8623, 0.37050299531892483)]
# 74099
# [(2, 0.1928901490174598), (120, 0.3179172861315156), (160, 0.2646278830605908), (239, 0.4040198134153994), (761, 0.4773668830468314), (4331, 0.6329162049083616)]
# 74043
# [(164, 0.12842800608898117), (406, 0.26232690199996306), (455, 0.21936155383778227), (552, 0.3486448380341408), (629, 0.2811298058617831), (845, 0.16705289388604236), (2503, 0.24904284154507847), (4620, 0.3069143509880034), (10064, 0.41248820035896083), (20018, 0.5583119388361117)]
# 27947
# [(85, 0.3897078382571144), (451, 0.15933294808867318), (472, 0.121362725791603), (3675, 0.1568899519796039), (3786, 0.2424493136922233), (4569, 0.7983384556656541), (12571, 0.295417475289051)]
# 45147
# [(2, 0.5387935661786442), (781, 0.8424378274059747)]
# 98548
# [(2, 0.10691135717876296), (18, 0.18937059284082408), (87, 0.2560291244925764), (250, 0.41158313656342016), (290, 0.1546872953821469), (527, 0.23701984956905342), (587, 0.13823492297951248), (868, 0.2007022742340966), (882, 0.2662703281172701), (1327, 0.2764262952423129), (7370, 0.4966616317513481), (12456, 0.4292739490514657)]
# 48111
# [(283, 0.2969900678401463), (1036, 0.4603415223544603), (1122, 0.3533997280716888), (1440, 0.4289929136794102), (10425, 0.6252649795185956)]
# 35835
# [(272, 0.2975152447928601), (1963, 0.4488054307789315), (21551, 0.8426496095170175)]
# 59578
# [(13, 0.1536345030944529), (85, 0.25319062091596917), (164, 0.16450682217392748), (2241, 0.43578459730098623), (4076, 0.4413893933245178), (4870, 0.446139714198167), (14170, 0.549049176329727)]
# 57218
# [(85, 0.7257651311190321), (691, 0.6879425662450129)]

# %%
search_accuracy_tfidf(14773)
# Out:
# [(263, 0.222092466594778), (593, 0.31058804801441875), (603, 0.1842142444074801), (773, 0.21790126932819534), (1147, 0.3292517581948753), (8359, 0.42421535873496063), (14691, 0.4612154931102332), (21631, 0.5212571608611428)]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-20-818bdf2d2bd3> in <module>()
# ----> 1 search_accuracy_tfidf(14773)
#
# <ipython-input-17-034e267c3b5b> in search_accuracy_tfidf(index)
#       9     doc_tfidf = tfidf[doc_bow]
#      10     print doc_tfidf
# ---> 11     sims_tfidf = artist_index_dict[ref_artist_id][doc_tfidf]
#      12     sims_tfidf = sorted(enumerate(sims_tfidf),
#      13                         key=lambda item: item[1], reverse=True)
#
# /Users/nehemiahloury/anaconda/envs/dsi/lib/python2.7/site-packages/gensim/interfaces.py in __getitem__(self, query)
#     216                 else:
#     217                     query = matutils.unitvec(query)
# --> 218         result = self.get_similarities(query)
#     219
#     220         if self.num_best is None:
#
# /Users/nehemiahloury/anaconda/envs/dsi/lib/python2.7/site-packages/gensim/similarities/docsim.py in get_similarities(self, query)
#     558             else:
#     559                 # default case: query is a single vector in sparse gensim format
# --> 560                 query = matutils.sparse2full(query, self.num_features)
#     561             query = numpy.asarray(query, dtype=self.index.dtype)
#     562
#
# /Users/nehemiahloury/anaconda/envs/dsi/lib/python2.7/site-packages/gensim/matutils.py in sparse2full(doc, length)
#     207     doc = dict(doc)
#     208     # overwrite some of the zeroes with explicit values
# --> 209     result[list(doc)] = list(itervalues(doc))
#     210     return result
#     211
#
# IndexError: index 21631 is out of bounds for axis 1 with size 14909

# %% [markdown]
# ## Latent Semantic Analysis and Similarity Calcuation

# %%
# LSI our Tf-idf corpus
lsa = models.LsiModel(corpus_tfidf, id2word=dictionary, num_topics=10)
corpus_lsa = lsa[corpus_tfidf]

# %%
# Create indices for querying separated by artist_id
artist_lsa_index_dict = {}
for key, value in artist_corpus_dict.iteritems():
    artist_lsa_index_dict[key] = similarities.MatrixSimilarity(lsa[tfidf[value]])

# %%
# Create Function for calucating TFIDF searcha accuracy
def search_accuracy_lsa(index):
    ref_artist_id = all_data.iloc[index, :]['artist_id']
    ref_ann_id = all_data.iloc[index, :]['ann_id']
    artist_df = all_data[all_data['artist_id'] == ref_artist_id].reset_index(drop=True)
    ref_position = artist_df[artist_df['ann_id'] == ref_ann_id].index[0]
    doc = ref_text_bow[index]
    doc_bow = dictionary.doc2bow(doc)
    doc_lsa = lsa[tfidf[doc_bow]]
    sims_lsa = artist_lsa_index_dict[ref_artist_id][doc_lsa]
    sims_lsa = sorted(enumerate(sims_lsa), 
                        key=lambda item: item[1], reverse=True)
    sims_lsa = np.array(sims_lsa)
    correct_position = np.where(sims_lsa[:, 0] == ref_position)[0][0] # Find Ranking Position of correct annotation
    percentile = 1 - correct_position/float(sims_lsa.shape[0]) # Find Percentile Ranking
    return correct_position, percentile

# %%
scores = []
for idx in ref_indices:
    print idx
    accuracy = search_accuracy_lsa(idx)
    scores.append(accuracy)
# Out:
# 50888
# 34177
# 63751
# 69840
# 3637
# 56152
# 9336
# 64695
# 23115
# 72805
# 103605
# 48527
# 95573
# 98754
# 4720
# 50798
# 10238
# 1060
# 80604
# 31880
# 70562
# 92846
# 15031
# 57455
# 6056
# 54067
# 99629
# 69430
# 102405
# 14601
# 53218
# 93046
# 57359
# 14598
# 13031
# 47215
# 54157
# 82292
# 50881
# 1420
# 72666
# 61452
# 2753
# 41670
# 14122
# 83697
# 56192
# 51304
# 88004
# 100376
# 55881
# 42496
# 32721
# 70868
# 16769
# 71393
# 23784
# 78035
# 74103
# 98915
# 23777
# 72017
# 52724
# 62588
# 78667
# 51693
# 78602
# 11127
# 55941
# 65487
# 1883
# 69675
# 70366
# 18371
# 80994
# 60899
# 23945
# 62909
# 38680
# 102909
# 28261
# 98326
# 78245
# 101999
# 77325
# 60001
# 48634
# 16292
# 63435
# 9188
# 20587
# 74099
# 74043
# 27947
# 45147
# 98548
# 48111
# 35835
# 59578
# 57218

# %%
# Find position of the "correct" annotation in the similarity list
correct_position = np.where(sims_lsa[:, 0] == index)[0]
correct_position

# %%
# Repeat for sample of test queries
correct_positions = np.zeros(5)
for i in range(5):
    doc = ref_text_bow[i]
    index = ann_index[i]
    doc_bow = dictionary.doc2bow(doc)
    doc_tfidf = tfidf[doc_bow]
    doc_lsa = lsa[doc_tfidf]

    # Query our index for closely related documents
    sims_lsa = index_lsa[doc_lsa]
    sims_lsa = sorted(enumerate(sims_lsa), 
                        key=lambda item: item[1], reverse=True)
    sims_lsa = np.array(sims_lsa)
    correct_position = np.where(sims_lsa[:, 0] == index)[0]
    print correct_position
    correct_positions[i] = correct_position

# %% [markdown]
# ## Latent Dirichlet Allocation and Similarity Calculation

# %%
# LDA our BOW corpus
lda = models.LdaModel(corpus, id2word=dictionary, num_topics=5)
corpus_lda = lda[corpus]

# %%
# Print first ten documents in our LDA corpus
for i in corpus_lda[:5]:
    print i
# Out:
# [(1, 0.13106263717234684), (2, 0.70330932327740769), (4, 0.15845293007370048)]
# [(0, 0.010815749492938528), (1, 0.12333716806465662), (2, 0.78145765402605971), (3, 0.073827878405082495), (4, 0.0105615500112626)]
# [(2, 0.36012623594661347), (4, 0.61327365359313557)]
# [(0, 0.046939960071494792), (2, 0.14330507832413031), (4, 0.79908502909962764)]
# [(0, 0.67258756719662194), (1, 0.029010811905071092), (2, 0.24084909912011762), (3, 0.028814185610665444), (4, 0.028738336167523849)]

# %%
# Create index for querying
index_lda = similarities.MatrixSimilarity(corpus_lda)

# %%
# Create LDA representation of our test query (referent)
doc = ref_text_bow[2]
index = ann_index[2]
doc_bow = dictionary.doc2bow(doc)
doc_lda = lda[doc_bow]

# Query our index for closely related documents
sims_lda = index_lda[doc_lda]
sims_lda = sorted(enumerate(sims_lda), 
                    key=lambda item: item[1], reverse=True)
sims_lda = np.array(sims_lda)

# %%
# Find position of the "correct" annotation in the similarity list
correct_position = np.where(sims_lsa[:, 0] == index)[0]
correct_position
# Out:
# array([72390])

# %%
# Repeat for sample of test queries
correct_positions = np.zeros(5)
for i in range(5):
    doc = ref_text_bow[i]
    index = ann_index[i]
    doc_bow = dictionary.doc2bow(doc)
    doc_lda = lda[doc_bow]

    # Query our index for closely related documents
    sims_lda = index_lsa[doc_lda]
    sims_lda = sorted(enumerate(sims_lda), 
                        key=lambda item: item[1], reverse=True)
    sims_lda = np.array(sims_lsa)
    correct_position = np.where(sims_lda[:, 0] == index)[0]
    print correct_position
    correct_positions[i] = correct_position
# Out:
# [82307]
# [71095]
# [72390]
# [83366]
# [98836]

# %%
print ref_text[4]
for i in sims_lda[:5,0]:
    print ann_text[i] + "\n\n---\n\n"
# Out:
# [Bridge]
#  Whole squad on that real shit
#  Whole squad on that real shit
#  Whole squad on that real shit
#
#
# ---
#
#
# Reference to Redmans hit Tonights Da Night
#
# ACCEPTED COMMENT: https://www.youtube.com/watch?v=G6LVIi7pzZI
#
# ---
#
#
# Lil Yachty- u trippin
#
# ---
#
#
# Em is referring to the same Van Dyke Avenue in Yellow Brick Road from his Encore album.
# This is also a play on words, knowing how much Eminem loves disrespecting women and talking about lesbians, which is shadowing his urge to want to call the girl hes with a dyke (lesbian).
#
# Van Dyke Avenue is a street/road in Detroit crossing 8 Mile Road.
# Its quite long, too:
# Van Dyke
#
# ---
#
#
# Ready to Die
#
# ---

# %% [markdown]
# ## Hierarchical Dirichlet Process and Similarity Calculation

# %%
# HDP our BOW corpus
hdp = models.HdpModel(corpus, id2word=dictionary)
corpus_hdp = hdp[corpus]
