# %%
import numpy as np
import pandas as pd
import psycopg2 as psy
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sb
import pickle as pic

# %matplotlib inline

# %%
# Connect to the Lyrics Database
conn = psy.connect("dbname=test")
cur = conn.cursor()

# %%
# Put Data in Pandas DataFrame
songs = pd.read_sql_query("SELECT * FROM songs;", conn)
refs = pd.read_sql_query("SELECT * FROM referents;", conn)
anns = pd.read_sql_query("SELECT * FROM annotations;", conn)

# %%
# Songs DataFrame Info
print songs.shape
print songs.info()
songs.head()
# Out:
# (8007, 8)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8007 entries, 0 to 8006
# Data columns (total 8 columns):
# song_id                   8007 non-null int64
# hot                       8007 non-null bool
# unreviewed_annotations    8007 non-null int64
# title                     8007 non-null object
# full_title                8007 non-null object
# artist                    8007 non-null object
# artist_id                 8007 non-null int64
# annotation_count          8007 non-null int64
# dtypes: bool(1), int64(4), object(3)
# memory usage: 445.8+ KB
# None
#    song_id    hot  unreviewed_annotations                    title  \
# 0  2890384  False                       0                    0-100
# 1   156640  False                       0  0 to 100 / The Catch Up
# 2  2136824  False                       0                      100
# 3  2688225  False                       0              100it Racks
# 4   703738  False                       2                 10 Bands
#
#                                           full_title      artist  artist_id  \
# 0                                0-100 by John Nonny  John Nonny    1020738
# 1                   0 to 100 / The Catch Up by Drake       Drake        130
# 2                        100 by The Game (Ft. Drake)    The Game         42
# 3  100it Racks by DJ Esco (Ft. 2 Chainz, Drake & ...     DJ Esco      49470
# 4                                  10 Bands by Drake       Drake        130
#
#    annotation_count
# 0                 0
# 1                41
# 2                43
# 3                50
# 4                30

# %%
# Referent DataFrame Info
print refs.shape
print refs.info()
refs.head()
# Out:
# (98995, 6)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98995 entries, 0 to 98994
# Data columns (total 6 columns):
# id                98995 non-null int64
# song_id           98995 non-null int64
# classification    98995 non-null object
# fragment          98992 non-null object
# is_description    98995 non-null bool
# annotator_id      98995 non-null int64
# dtypes: bool(1), int64(3), object(2)
# memory usage: 3.9+ MB
# None
#         id  song_id classification  \
# 0  4961787   156640       accepted
# 1  3274596   156640       accepted
# 2  3272685   156640       accepted
# 3  3272333   156640       accepted
# 4  3272181   156640       accepted
#
#                                             fragment is_description  \
# 0                                 [Part I: 0 to 100]          False
# 1  [Produced by Boi-1da, Frank Dukes, Noah "40" S...          False
# 2  Maybe I'm searchin' for the problems, askin' w...          False
# 3  The other night, Lavish Lee told me that I'm a...          False
# 4  [Bridge]\n Whole squad on that real shit\n Who...          False
#
#    annotator_id
# 0        605899
# 1        104344
# 2         58812
# 3        658401
# 4         18490

# %%
# Annotation DataFrame Info
print anns.shape
print anns.info()
anns.head()
# Out:
# (98931, 12)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98931 entries, 0 to 98930
# Data columns (total 12 columns):
# id               98931 non-null int64
# song_id          98931 non-null int64
# ref_id           98931 non-null int64
# ann_text         98931 non-null object
# verified         98931 non-null bool
# cosigned_by      98931 non-null object
# has_voters       98931 non-null bool
# state            98931 non-null object
# community        98931 non-null bool
# pinned           98931 non-null bool
# comment_count    98931 non-null int64
# votes_total      98931 non-null int64
# dtypes: bool(4), int64(5), object(3)
# memory usage: 6.4+ MB
# None
#         id  song_id   ref_id  \
# 0  4961787   156640  4961787
# 1  3274596   156640  3274596
# 2  3272685   156640  3272685
# 3  3272333   156640  3272333
# 4  3272181   156640  3272181
#
#                                             ann_text verified cosigned_by  \
# 0  This song was allegedly supposed to be Diddy’s...    False          {}
# 1  https://twitter.com/Boi1da/status/473262859418...    False          {}
# 2  Like he says in “Think Good,” Drake is constan...    False          {}
# 3  Lavish Lee is the best friend of Melissa Shay ...    False          {}
# 4  Drake’s only squads are OVO (and TOPSZN lowkey...    False          {}
#
#   has_voters     state community pinned  comment_count  votes_total
# 0       True  accepted      True  False              0           11
# 1       True  accepted      True  False              0           56
# 2       True  accepted      True  False              0           19
# 3       True  accepted      True  False              0           37
# 4       True  accepted      True  False              0           44

# %%
# Drop Empty Referents
refs.dropna(axis=0, how='any', inplace=True)

# %%
refs['fragment'][19]
# Out:
# 'But when they need a favor, who do they call?'

# %%
# Change UTF-8 to ASCII
# Define Genius Decoder Function
def genius_decoder(x):
    if x:
        return x.decode('utf8').encode('ascii', 'ignore')
    else:
        return x

# Decode Referents and Annotations    
refs['fragment'] = refs['fragment'].apply(genius_decoder)
anns['ann_text'] = anns['ann_text'].apply(genius_decoder)

# %%
# Referent Classification Counts
print refs.classification.value_counts()
refs.groupby('classification').size().plot(kind='bar')
# Out:
# accepted         79325
# unreviewed       18229
# verified          1376
# cosigned            48
# being_created       14
# Name: classification, dtype: int64

# %%
# Number of Referents per song
print refs.groupby('song_id').size().describe()
refs.groupby('song_id').size().hist()
plt.xlabel('Number of Referents')
plt.ylabel('Count')
# Out:
# count    5098.000000
# mean       19.417811
# std        19.403525
# min         1.000000
# 25%         5.000000
# 50%        13.000000
# 75%        29.000000
# max       257.000000
# dtype: float64

# %%
# Length of Referents
# Split referent fragments in order to count words
ref_length = refs['fragment'].apply(lambda x: len(x.split()))

# Referent Length with Outliers Removed 
ref_length[ref_length < 46].hist()
plt.title('Histogram of Referent Length with Outliers Removed')
plt.xlabel('Referent Length (Words)')
plt.ylabel('Count')
plt.show()

# Log Referent Length with Outliers Included
np.log1p(ref_length).hist()
plt.title('Histogram of Log Referent Length')
plt.xlabel('Log Referent Length (Words)')
plt.ylabel('Count')
plt.show()

# %%
# Verified vs Unverified Annotations
print anns['verified'].value_counts()
anns.groupby('verified').size().plot(kind='bar')
# Out:
# False    97560
# True      1371
# Name: verified, dtype: int64

# %%
# Pinned vs Unpinned Annotations
print anns['pinned'].value_counts()
anns.groupby('pinned').size().plot(kind='bar')
# Out:
# False    97810
# True      1121
# Name: pinned, dtype: int64

# %%
# Annotation State
print anns['state'].value_counts()
anns.groupby('state').size().plot(kind='bar')
# Out:
# accepted         79331
# pending          18233
# verified          1353
# being_created       14
# Name: state, dtype: int64

# %%
# Annotation Comment Count
print anns['comment_count'].value_counts()

# Annotations < 10 Comments Histogram
anns['comment_count'][anns['comment_count'] < 10].hist()
plt.show()

# Annotations < 10 Comments Histogram
np.log1p(anns['comment_count']).hist()
plt.show()
# Out:
# 0      81390
# 1      11790
# 2       3410
# 3       1197
# 4        510
# 5        243
# 6        116
# 7         59
# 8         57
# 9         20
# 11        18
# 10        16
# 12        14
# 16        11
# 14         7
# 13         6
# 15         5
# 32         4
# 25         4
# 22         3
# 17         3
# 18         3
# 19         3
# 20         3
# 81         2
# 21         2
# 34         2
# 24         2
# 26         2
# 27         2
# 29         2
# 56         2
# 36         2
# 37         2
# 23         2
# 52         1
# 51         1
# 67         1
# 57         1
# 54         1
# 69         1
# 64         1
# 50         1
# 42         1
# 47         1
# 44         1
# 106        1
# 232        1
# 40         1
# 33         1
# 28         1
# 59         1
# Name: comment_count, dtype: int64

# %%
# Annotation Vote Totals
votes = anns['votes_total']
print anns['votes_total'].describe()

# Annotation Vote Total Histogram
votes[(votes > 0) & (votes < 50)].hist()
plt.show()
# Out:
# count    98931.000000
# mean         6.502623
# std         22.178921
# min       -652.000000
# 25%          0.000000
# 50%          1.000000
# 75%          5.000000
# max       1614.000000
# Name: votes_total, dtype: float64

# %%
# Length of Annotations
# Split annotation text in order to count words
ann_length = anns['ann_text'].apply(lambda x: len(x.split()))
print ann_length.describe()

# Annotation Length with Outliers Removed 
ann_length[ann_length < 142].hist()
plt.title('Histogram of Annotation Length with Outliers Removed')
plt.xlabel('Annotation Length (Words)')
plt.ylabel('Count')
plt.show()

# Log Annotation Length with Outliers Included
np.log1p(ref_length).hist()
plt.title('Histogram of Log Annotation Length')
plt.xlabel('Log Annotation Length (Words)')
plt.ylabel('Count')
plt.show()
# Out:
# count    98931.000000
# mean        36.973032
# std         35.218297
# min          0.000000
# 25%         15.000000
# 50%         27.000000
# 75%         48.000000
# max       1095.000000
# Name: ann_text, dtype: float64

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import Normalizer
from sklearn.pipeline import make_pipeline
import nltk, string

# %%
# LSA for Information Retrieval
# Create Stemmer
stemmer = nltk.stem.porter.PorterStemmer()
trans_table = {ord(c): None for c in string.punctuation}
# Define Preprocessing Functions
def stem_tokens(tokens):
    return [stemmer.stem(item) for item in tokens]

def normalize(text):
    return stem_tokens(nltk.word_tokenize(text.lower().translate(trans_table)))

# %%
# Tfidf Vectorizer
# - Strip out "stop words"
# - Normalize by Stemming, lowering the case, and removing punctuation

vectorizer = TfidfVectorizer(tokenizer=normalize, max_df=0.5, 
                             max_features=10000, min_df=2, 
                             stop_words='english', use_idf=True)


# Vectorize the annotations
annotations = anns['ann_text'].values
ann_tfidf = vectorizer.fit_transform(annotations)

# %%
feat_names = vectorizer.get_feature_names()

# %%
# Perform Latent Semantic Analysis on annotations
svd = TruncatedSVD(100)
lsa = make_pipeline(svd, Normalizer(copy=False))
X_train_lsa = lsa.fit_transform(ann_tfidf)

# %%
for compNum in range(0, 10):

    comp = svd.components_[compNum]
    
    # Sort the weights in the first component, and get the indeces
    indeces = np.argsort(comp).tolist()
    
    # Reverse the indeces, so we have the largest weights first.
    indeces.reverse()
    
    # Grab the top 10 terms which have the highest weight in this component.        
    terms = [feat_names[weightIndex] for weightIndex in indeces[0:10]]    
    weights = [comp[weightIndex] for weightIndex in indeces[0:10]]    
   
    # Display these terms and their weights as a horizontal bar graph.    
    # The horizontal bar graph displays the first item on the bottom; reverse
    # the order of the terms so the biggest one is on top.
    terms.reverse()
    weights.reverse()
    positions = range(1,11)    # the bar centers on the y axis
    
    plt.figure(compNum)
    plt.barh(positions, weights, align='center')
    plt.yticks(positions, terms)
    plt.xlabel('Weight')
    plt.title('Strongest terms for component %d' % (compNum))
    plt.grid(True)
    plt.show()

# %%
# Pickle our databases
pic.dump(songs, open("./Data/songs.p", "wb"))
pic.dump(refs, open("./Data/referents.p", "wb"))
pic.dump(anns, open("./Data/annotations.p", "wb"))
